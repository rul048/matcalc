# %% [markdown]
# # Introduction
#
# This notebook demonstrates how to run the MatCalc-Benchmark. We will use the recently released TensorNet-PES-MatPES-PBE-2025.2 and MACE-MPA-0 universal machine learning interatomic potentials for demonstration purposes. All that is needed to run the benchmark on a separate model is to provide a compatible ASE Calculator for your FP.

# %%
from __future__ import annotations

import warnings

import matgl
import numpy as np
import pandas as pd

from matcalc.benchmark import ElasticityBenchmark

# %% [markdown]
# # Elasticity Benchmark
#
# For demonstration purposes only, we will sample 10 structures from the entire test dataset.

# %%
benchmark = ElasticityBenchmark(n_samples=10, seed=2025, fmax=0.05, relax_structure=True)
results = {}
for model_name in [
    "MACE",
    "TensorNet-PES-MatPES-PBE-2025.2"
]:
    short_name = model_name.split("-")[0]
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        results[short_name] = benchmark.run(model_name, short_name)
# Out:
# WARNING:root:Default dtype float32 does not match model dtype float64, converting models to float32.
# Using medium MPA-0 model as default MACE-MP model, to use previous (before 3.10) default model please specify 'medium' as model argument
# Using Materials Project MACE for MACECalculator with /Users/shyue/.cache/mace/macempa0mediummodel
# Using float32 for MACECalculator, which is faster but less accurate. Recommended for MD. Use float64 for geometry optimization.
#   0%|                                                                                                                        | 0/10 [00:00<?, ?it/s]/Users/shyue/repos/matcalc/.venv/lib/python3.11/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# /Users/shyue/repos/matcalc/.venv/lib/python3.11/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:04<00:00,  2.28it/s]
#   0%|                                                                                                                        | 0/10 [00:00<?, ?it/s]/Users/shyue/repos/matcalc/.venv/lib/python3.11/site-packages/matgl/graph/_converters_pyg.py:75: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:256.)
#   lattice = torch.as_tensor(lattice_matrix, dtype=matgl.float_th, device=device)
# /Users/shyue/repos/matcalc/.venv/lib/python3.11/site-packages/matgl/graph/_converters_pyg.py:75: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:256.)
#   lattice = torch.as_tensor(lattice_matrix, dtype=matgl.float_th, device=device)
# /Users/shyue/repos/matcalc/.venv/lib/python3.11/site-packages/matgl/graph/_converters_pyg.py:75: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:256.)
#   lattice = torch.as_tensor(lattice_matrix, dtype=matgl.float_th, device=device)
# /Users/shyue/repos/matcalc/.venv/lib/python3.11/site-packages/matgl/graph/_converters_pyg.py:75: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:256.)
#   lattice = torch.as_tensor(lattice_matrix, dtype=matgl.float_th, device=device)
# /Users/shyue/repos/matcalc/.venv/lib/python3.11/site-packages/matgl/graph/_converters_pyg.py:75: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:256.)
#   lattice = torch.as_tensor(lattice_matrix, dtype=matgl.float_th, device=device)
# /Users/shyue/repos/matcalc/.venv/lib/python3.11/site-packages/matgl/graph/_converters_pyg.py:75: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:256.)
#   lattice = torch.as_tensor(lattice_matrix, dtype=matgl.float_th, device=device)
# /Users/shyue/repos/matcalc/.venv/lib/python3.11/site-packages/matgl/graph/_converters_pyg.py:75: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:256.)
#   lattice = torch.as_tensor(lattice_matrix, dtype=matgl.float_th, device=device)
# /Users/shyue/repos/matcalc/.venv/lib/python3.11/site-packages/matgl/graph/_converters_pyg.py:75: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:256.)
#   lattice = torch.as_tensor(lattice_matrix, dtype=matgl.float_th, device=device)
# /Users/shyue/repos/matcalc/.venv/lib/python3.11/site-packages/matgl/graph/_converters_pyg.py:75: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:256.)
#   lattice = torch.as_tensor(lattice_matrix, dtype=matgl.float_th, device=device)
#  10%|███████████▏                                                                                                    | 1/10 [00:00<00:07,  1.15it/s]/Users/shyue/repos/matcalc/.venv/lib/python3.11/site-packages/matgl/graph/_converters_pyg.py:75: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:256.)
#   lattice = torch.as_tensor(lattice_matrix, dtype=matgl.float_th, device=device)
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:05<00:00,  1.87it/s]

# %%
results
# Out:
# {'MACE':        mp_id formula  K_vrh_DFT  G_vrh_DFT  K_vrh_MACE  G_vrh_MACE
#  0   mp-11536   NpRh3    215.446     71.946         NaN         NaN
#  1    mp-7951   ThSe2     77.932     26.736         NaN         NaN
#  2  mp-985300   AcEr3     37.450     20.758         NaN         NaN
#  3   mp-30355    SrAg     27.873     13.764         NaN         NaN
#  4  mp-865382    V3Ru    221.654     89.252         NaN         NaN
#  5  mp-545512     CaO     86.059     34.214         NaN         NaN
#  6   mp-30371  Cd5Au3     73.514     11.916         NaN         NaN
#  7    mp-1609   Cr3Ir    275.177    107.470         NaN         NaN
#  8  mp-867189   Pm3Pb     44.905     22.668         NaN         NaN
#  9    mp-1697   TbPt2    163.153     73.747         NaN         NaN,
#  'TensorNet':        mp_id formula  K_vrh_DFT  G_vrh_DFT  K_vrh_TensorNet  G_vrh_TensorNet
#  0   mp-11536   NpRh3    215.446     71.946       184.907559        76.761086
#  1    mp-7951   ThSe2     77.932     26.736        68.346055        24.974554
#  2  mp-985300   AcEr3     37.450     20.758        23.318527        15.374792
#  3   mp-30355    SrAg     27.873     13.764        29.822254        14.500085
#  4  mp-865382    V3Ru    221.654     89.252       250.800669        81.854519
#  5  mp-545512     CaO     86.059     34.214        83.306616        50.995794
#  6   mp-30371  Cd5Au3     73.514     11.916        68.635070        15.029149
#  7    mp-1609   Cr3Ir    275.177    107.470       214.210929       103.948196
#  8  mp-867189   Pm3Pb     44.905     22.668        31.940397        14.591016
#  9    mp-1697   TbPt2    163.153     73.747       130.756794        48.443972}

# %%
df = pd.merge(results["MACE"], results["TensorNet"], on="mp_id", how="inner", suffixes=(None, "_dupe"))

# %%
# To dump the results to a csv file, uncomment the code below.
# results.to_csv("MatCalc-Benchmark-elasticity.csv")
df
# Out:
#        mp_id formula  K_vrh_DFT  G_vrh_DFT  K_vrh_MACE  G_vrh_MACE  \
# 0   mp-11536   NpRh3    215.446     71.946         NaN         NaN
# 1    mp-7951   ThSe2     77.932     26.736         NaN         NaN
# 2  mp-985300   AcEr3     37.450     20.758         NaN         NaN
# 3   mp-30355    SrAg     27.873     13.764         NaN         NaN
# 4  mp-865382    V3Ru    221.654     89.252         NaN         NaN
# 5  mp-545512     CaO     86.059     34.214         NaN         NaN
# 6   mp-30371  Cd5Au3     73.514     11.916         NaN         NaN
# 7    mp-1609   Cr3Ir    275.177    107.470         NaN         NaN
# 8  mp-867189   Pm3Pb     44.905     22.668         NaN         NaN
# 9    mp-1697   TbPt2    163.153     73.747         NaN         NaN
#
#   formula_dupe  K_vrh_DFT_dupe  G_vrh_DFT_dupe  K_vrh_TensorNet  \
# 0        NpRh3         215.446          71.946       184.907559
# 1        ThSe2          77.932          26.736        68.346055
# 2        AcEr3          37.450          20.758        23.318527
# 3         SrAg          27.873          13.764        29.822254
# 4         V3Ru         221.654          89.252       250.800669
# 5          CaO          86.059          34.214        83.306616
# 6       Cd5Au3          73.514          11.916        68.635070
# 7        Cr3Ir         275.177         107.470       214.210929
# 8        Pm3Pb          44.905          22.668        31.940397
# 9        TbPt2         163.153          73.747       130.756794
#
#    G_vrh_TensorNet
# 0        76.761086
# 1        24.974554
# 2        15.374792
# 3        14.500085
# 4        81.854519
# 5        50.995794
# 6        15.029149
# 7       103.948196
# 8        14.591016
# 9        48.443972
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.

# %%
for c in df.columns:
    if c.startswith("K") or c.startswith("G"):
        df[f"AE {c}"] = np.abs(df[c] - df[f"{c.split('_')[0]}_vrh_DFT"])
        print(f"MAE {c} = {df[f'AE {c}'].mean():.1f}")

# %% [markdown]
# # Statistical significance test
#
# When comparing the performance of models, it is important to not just look at the final MAE but also to perform a rigorous statistical test of whether there is a significant difference between the MAEs. Since the model predictions are for the same set of compounds, this can be done using the paired t-test. See: https://www.jmp.com/en/statistics-knowledge-portal/t-test/two-sample-t-test

# %%
from scipy.stats import ttest_rel

# %%
print(ttest_rel(df["AE K_vrh_TensorNet"], df["AE K_vrh_M3GNet"]))
print(ttest_rel(df["AE G_vrh_TensorNet"], df["AE G_vrh_M3GNet"]))

# %% [markdown]
# At an alpha of 5%, the p value show that we **reject the null hypothesis that the MAEs in K of the two models are the same**, i.e., the difference in MAEs in K of the two models is statistically significant. However, we **do not reject the null hypothesis that the MAEs in G of the two models are the same**, i.e., the difference in MAEs in G of the two models is not statistically significant.
